# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import re

# %%
df=pd.read_csv(r"C:\Users\Jyothi\Desktop\Projects\us_housing\US Housing dataset.csv")

# %%
df
# Out:
#           DATE  ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0     1/1/1962          0.103627            0.170213         -0.086294
# 1     2/1/1962          0.103627            0.170213         -0.086294
# 2     3/1/1962          0.103627            0.170213         -0.086294
# 3     4/1/1962          0.103627            0.170213         -0.086294
# 4     5/1/1962          0.103627            0.170213         -0.086294
# ..         ...               ...                 ...               ...
# 679   8/1/2018          0.077628            0.067797          0.317982
# 680   9/1/2018          0.045996            0.105263          0.279412
# 681  10/1/2018          0.042461            0.309091          0.089286
# 682  11/1/2018          0.051818            0.288462          0.121723
# 683  12/1/2018          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# ...

# %%
df.shape
# Out:
# (684, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684 entries, 0 to 683
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATE                      684 non-null    object
#  1   ASPUS_3A_PCT_CHG          684 non-null    float64
#  2   H_RATIO_3A_PCT_CHG        684 non-null    float64
#  3   HSN1F_3A_PCT_CHG          684 non-null    float64
#  4   PERMIT_3A_PCT_CHG         684 non-null    float64
#  5   STOCK_MKT_3A_PCT_CHG      684 non-null    float64
#  6   BAA_YEILD_10Y_2A_PCT_CHG  684 non-null    float64
#  7   US10Y_3A_PCT_CHG          684 non-null    float64
#  8   RPCE_A_PCT_CHG            684 non-null    float64
#  9   UEMP_3A_PCT_CHG           684 non-null    float64
#  10  RGDP_M_PCT_CHG            684 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 58.9+ KB

# %%
df.isnull().sum()
# Out:
# DATE                        0
# ASPUS_3A_PCT_CHG            0
# H_RATIO_3A_PCT_CHG          0
# HSN1F_3A_PCT_CHG            0
# PERMIT_3A_PCT_CHG           0
# STOCK_MKT_3A_PCT_CHG        0
# BAA_YEILD_10Y_2A_PCT_CHG    0
# US10Y_3A_PCT_CHG            0
# RPCE_A_PCT_CHG              0
# UEMP_3A_PCT_CHG             0
# RGDP_M_PCT_CHG              0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df['BAA_YEILD_10Y_2A_PCT_CHG']=(df['BAA_YEILD_10Y_2A_PCT_CHG']*3)/2

# %%
df
# Out:
#           DATE  ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0     1/1/1962          0.103627            0.170213         -0.086294
# 1     2/1/1962          0.103627            0.170213         -0.086294
# 2     3/1/1962          0.103627            0.170213         -0.086294
# 3     4/1/1962          0.103627            0.170213         -0.086294
# 4     5/1/1962          0.103627            0.170213         -0.086294
# ..         ...               ...                 ...               ...
# 679   8/1/2018          0.077628            0.067797          0.317982
# 680   9/1/2018          0.045996            0.105263          0.279412
# 681  10/1/2018          0.042461            0.309091          0.089286
# 682  11/1/2018          0.051818            0.288462          0.121723
# 683  12/1/2018          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# ...

# %%
df['RPCE_A_PCT_CHG']=df['RPCE_A_PCT_CHG']*3

# %%
df
# Out:
#           DATE  ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0     1/1/1962          0.103627            0.170213         -0.086294
# 1     2/1/1962          0.103627            0.170213         -0.086294
# 2     3/1/1962          0.103627            0.170213         -0.086294
# 3     4/1/1962          0.103627            0.170213         -0.086294
# 4     5/1/1962          0.103627            0.170213         -0.086294
# ..         ...               ...                 ...               ...
# 679   8/1/2018          0.077628            0.067797          0.317982
# 680   9/1/2018          0.045996            0.105263          0.279412
# 681  10/1/2018          0.042461            0.309091          0.089286
# 682  11/1/2018          0.051818            0.288462          0.121723
# 683  12/1/2018          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# ...

# %%
df['DATE']=pd.to_datetime(df['DATE'])

# %%
df
# Out:
#           DATE  ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0   1962-01-01          0.103627            0.170213         -0.086294
# 1   1962-02-01          0.103627            0.170213         -0.086294
# 2   1962-03-01          0.103627            0.170213         -0.086294
# 3   1962-04-01          0.103627            0.170213         -0.086294
# 4   1962-05-01          0.103627            0.170213         -0.086294
# ..         ...               ...                 ...               ...
# 679 2018-08-01          0.077628            0.067797          0.317982
# 680 2018-09-01          0.045996            0.105263          0.279412
# 681 2018-10-01          0.042461            0.309091          0.089286
# 682 2018-11-01          0.051818            0.288462          0.121723
# 683 2018-12-01          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# ...

# %%
df['YEAR']=df['DATE'].dt.year

# %%
df
# Out:
#           DATE  ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0   1962-01-01          0.103627            0.170213         -0.086294
# 1   1962-02-01          0.103627            0.170213         -0.086294
# 2   1962-03-01          0.103627            0.170213         -0.086294
# 3   1962-04-01          0.103627            0.170213         -0.086294
# 4   1962-05-01          0.103627            0.170213         -0.086294
# ..         ...               ...                 ...               ...
# 679 2018-08-01          0.077628            0.067797          0.317982
# 680 2018-09-01          0.045996            0.105263          0.279412
# 681 2018-10-01          0.042461            0.309091          0.089286
# 682 2018-11-01          0.051818            0.288462          0.121723
# 683 2018-12-01          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# ...

# %%
df['MONTH']=df['DATE'].dt.month

# %%
df
# Out:
#           DATE  ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0   1962-01-01          0.103627            0.170213         -0.086294
# 1   1962-02-01          0.103627            0.170213         -0.086294
# 2   1962-03-01          0.103627            0.170213         -0.086294
# 3   1962-04-01          0.103627            0.170213         -0.086294
# 4   1962-05-01          0.103627            0.170213         -0.086294
# ..         ...               ...                 ...               ...
# 679 2018-08-01          0.077628            0.067797          0.317982
# 680 2018-09-01          0.045996            0.105263          0.279412
# 681 2018-10-01          0.042461            0.309091          0.089286
# 682 2018-11-01          0.051818            0.288462          0.121723
# 683 2018-12-01          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# ...

# %%
df.drop("DATE",axis=1,inplace = True)

# %%
df.head()
# Out:
#    ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  PERMIT_3A_PCT_CHG  \
# 0          0.103627            0.170213         -0.086294           0.037433
# 1          0.103627            0.170213         -0.086294           0.037433
# 2          0.103627            0.170213         -0.086294           0.037433
# 3          0.103627            0.170213         -0.086294           0.037433
# 4          0.103627            0.170213         -0.086294           0.037433
#
#    STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  US10Y_3A_PCT_CHG  \
# 0             -3.199388                     -0.42           0.02451
# 1             -3.199388                     -0.42           0.02451
# 2             -3.199388                     -0.42           0.02451
# 3             -3.199388                     -0.42           0.02451
# 4             -3.199388                     -0.42           0.02451
#
#    RPCE_A_PCT_CHG  UEMP_3A_PCT_CHG  RGDP_M_PCT_CHG  YEAR  MONTH
# ...

# %%
df2 = df[df.duplicated()]

# %%
df2
# Out:
# Empty DataFrame
# Columns: [ASPUS_3A_PCT_CHG, H_RATIO_3A_PCT_CHG, HSN1F_3A_PCT_CHG, PERMIT_3A_PCT_CHG, STOCK_MKT_3A_PCT_CHG, BAA_YEILD_10Y_2A_PCT_CHG, US10Y_3A_PCT_CHG, RPCE_A_PCT_CHG, UEMP_3A_PCT_CHG, RGDP_M_PCT_CHG, YEAR, MONTH]
# Index: []

# %%
df
# Out:
#      ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0            0.103627            0.170213         -0.086294
# 1            0.103627            0.170213         -0.086294
# 2            0.103627            0.170213         -0.086294
# 3            0.103627            0.170213         -0.086294
# 4            0.103627            0.170213         -0.086294
# ..                ...                 ...               ...
# 679          0.077628            0.067797          0.317982
# 680          0.045996            0.105263          0.279412
# 681          0.042461            0.309091          0.089286
# 682          0.051818            0.288462          0.121723
# 683          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# 0             0.037433             -3.199388                 -0.420000
# 1             0.037433             -3.199388                 -0.420000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684 entries, 0 to 683
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ASPUS_3A_PCT_CHG          684 non-null    float64
#  1   H_RATIO_3A_PCT_CHG        684 non-null    float64
#  2   HSN1F_3A_PCT_CHG          684 non-null    float64
#  3   PERMIT_3A_PCT_CHG         684 non-null    float64
#  4   STOCK_MKT_3A_PCT_CHG      684 non-null    float64
#  5   BAA_YEILD_10Y_2A_PCT_CHG  684 non-null    float64
#  6   US10Y_3A_PCT_CHG          684 non-null    float64
#  7   RPCE_A_PCT_CHG            684 non-null    float64
#  8   UEMP_3A_PCT_CHG           684 non-null    float64
#  9   RGDP_M_PCT_CHG            684 non-null    float64
#  10  YEAR                      684 non-null    int64
#  11  MONTH                     684 non-null    int64
# dtypes: float64(10), int64(2)
# memory usage: 64.2 KB

# %%
target_y=df['ASPUS_3A_PCT_CHG']
input_x=df.drop('ASPUS_3A_PCT_CHG',axis=1)

# %%
target_y
# Out:
# 0      0.103627
# 1      0.103627
# 2      0.103627
# 3      0.103627
# 4      0.103627
#          ...
# 679    0.077628
# 680    0.045996
# 681    0.042461
# 682    0.051818
# 683    0.061345
# Name: ASPUS_3A_PCT_CHG, Length: 684, dtype: float64

# %%
input_x.head(3)
# Out:
#    H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  PERMIT_3A_PCT_CHG  \
# 0            0.170213         -0.086294           0.037433
# 1            0.170213         -0.086294           0.037433
# 2            0.170213         -0.086294           0.037433
#
#    STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  US10Y_3A_PCT_CHG  \
# 0             -3.199388                     -0.42           0.02451
# 1             -3.199388                     -0.42           0.02451
# 2             -3.199388                     -0.42           0.02451
#
#    RPCE_A_PCT_CHG  UEMP_3A_PCT_CHG  RGDP_M_PCT_CHG  YEAR  MONTH
# 0       -0.348837        -0.207031       -0.164384  1962      1
# 1       -0.348837        -0.207031       -0.164384  1962      2
# 2       -0.348837        -0.207031       -0.196721  1962      3

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(input_x, target_y, train_size=0.80, random_state=100)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 547 entries, 577 to 520
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   H_RATIO_3A_PCT_CHG        547 non-null    float64
#  1   HSN1F_3A_PCT_CHG          547 non-null    float64
#  2   PERMIT_3A_PCT_CHG         547 non-null    float64
#  3   STOCK_MKT_3A_PCT_CHG      547 non-null    float64
#  4   BAA_YEILD_10Y_2A_PCT_CHG  547 non-null    float64
#  5   US10Y_3A_PCT_CHG          547 non-null    float64
#  6   RPCE_A_PCT_CHG            547 non-null    float64
#  7   UEMP_3A_PCT_CHG           547 non-null    float64
#  8   RGDP_M_PCT_CHG            547 non-null    float64
#  9   YEAR                      547 non-null    int64
#  10  MONTH                     547 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 51.3 KB

# %%
X_train.to_csv('train_data.csv',index=False)

# %%
x_train_num=X_train.select_dtypes(include=['float64','int64'])
x_train_num.head(3)
# Out:
#      H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  PERMIT_3A_PCT_CHG  \
# 577            0.050633         -0.596639          -0.592732
# 277           -0.252874          0.823529           0.865320
# 518           -0.046512          0.418803           0.235470
#
#      STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  US10Y_3A_PCT_CHG  \
# 577             -0.603045                 -0.323964         -0.190789
# 277             -2.109597                 -0.667742         -0.169553
# 518             -2.689000                 -0.690311         -0.136276
#
#      RPCE_A_PCT_CHG  UEMP_3A_PCT_CHG  RGDP_M_PCT_CHG  YEAR  MONTH
# 577       -8.255474         1.220152        0.488889  2010      2
# 277        0.590264        -0.192172       -0.025641  1985      2
# 518        1.644000        -0.090230       -0.238532  2005      3

# %%
from sklearn.preprocessing import StandardScaler
scaler_ = StandardScaler()

# %%
x_train_num_rescaled = pd.DataFrame(scaler_.fit_transform(x_train_num),
                                     columns = x_train_num.columns, 
                                    index = x_train_num.index)
x_train_num_rescaled.head()
# Out:
#      H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  PERMIT_3A_PCT_CHG  \
# 577           -0.049158         -1.952268          -1.699586
# 277           -0.858667          2.264427           1.966412
# 518           -0.308261          1.062734           0.382773
# 239            0.017855         -1.350303          -1.353707
# 664           -0.324584          1.161071           0.300114
#
#      STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  US10Y_3A_PCT_CHG  \
# 577              0.127540                 -0.588393         -0.762348
# 277             -0.419019                 -1.018147         -0.677724
# 518             -0.629220                 -1.046361         -0.545125
# 239             -0.394271                  1.217161          2.020949
# 664              0.149578                 -0.535419         -0.461876
#
#      RPCE_A_PCT_CHG  UEMP_3A_PCT_CHG  RGDP_M_PCT_CHG      YEAR     MONTH
# 577       -2.382794         3.268097        1.068472  1.211353 -1.353345
# ...

# %%
X_test.head()
# Out:
#      H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  PERMIT_3A_PCT_CHG  \
# 388           -0.242857          0.339147           0.448133
# 588           -0.247423         -0.482293          -0.431953
# 203           -0.046875          0.334992           0.521339
# 546            0.930233         -0.337872          -0.338035
# 436           -0.327586          0.223448           0.190805
#
#      STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  US10Y_3A_PCT_CHG  \
# 388             -1.566825                 -0.293296         -0.132850
# 588             -1.865174                 -0.722649         -0.093583
# 203             -1.411856                 -0.754011          0.164083
# 546             -0.716528                 -0.044118          0.168224
# 436             -0.033023                  0.161074         -0.084279
#
#      RPCE_A_PCT_CHG  UEMP_3A_PCT_CHG  RGDP_M_PCT_CHG  YEAR  MONTH
# 388       -0.801418        -0.099856       -0.187879  1994      5
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137 entries, 388 to 264
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   H_RATIO_3A_PCT_CHG        137 non-null    float64
#  1   HSN1F_3A_PCT_CHG          137 non-null    float64
#  2   PERMIT_3A_PCT_CHG         137 non-null    float64
#  3   STOCK_MKT_3A_PCT_CHG      137 non-null    float64
#  4   BAA_YEILD_10Y_2A_PCT_CHG  137 non-null    float64
#  5   US10Y_3A_PCT_CHG          137 non-null    float64
#  6   RPCE_A_PCT_CHG            137 non-null    float64
#  7   UEMP_3A_PCT_CHG           137 non-null    float64
#  8   RGDP_M_PCT_CHG            137 non-null    float64
#  9   YEAR                      137 non-null    int64
#  10  MONTH                     137 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 12.8 KB

# %%
x_test_num=X_test.select_dtypes(include=['int64','float64'])
x_test_num.head(3)
# Out:
#      H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  PERMIT_3A_PCT_CHG  \
# 388           -0.242857          0.339147           0.448133
# 588           -0.247423         -0.482293          -0.431953
# 203           -0.046875          0.334992           0.521339
#
#      STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  US10Y_3A_PCT_CHG  \
# 388             -1.566825                 -0.293296         -0.132850
# 588             -1.865174                 -0.722649         -0.093583
# 203             -1.411856                 -0.754011          0.164083
#
#      RPCE_A_PCT_CHG  UEMP_3A_PCT_CHG  RGDP_M_PCT_CHG  YEAR  MONTH
# 388       -0.801418        -0.099856       -0.187879  1994      5
# 588       -0.875000         0.811999       -1.150000  2011      1
# 203        0.260870        -0.284973       -0.410256  1978     12

# %%
x_test_num_rescaled = pd.DataFrame(scaler_.transform(x_test_num),
                                     columns = x_test_num.columns, 
                                    index = x_test_num.index)
x_test_num_rescaled.head()
# Out:
#      H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  PERMIT_3A_PCT_CHG  \
# 388           -0.831951          0.826223           0.917473
# 588           -0.844128         -1.612759          -1.295337
# 203           -0.309230          0.813884           1.101536
# 546            2.296901         -1.183951          -1.059199
# 436           -1.057940          0.482695           0.270469
#
#      STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  US10Y_3A_PCT_CHG  \
# 388             -0.222108                 -0.550055         -0.531473
# 588             -0.330345                 -1.086786         -0.375001
# 203             -0.165887                 -1.125991          0.651740
# 546              0.086370                 -0.238558          0.668243
# 436              0.334338                  0.017950         -0.337926
#
#      RPCE_A_PCT_CHG  UEMP_3A_PCT_CHG  RGDP_M_PCT_CHG      YEAR     MONTH
# 388       -0.238724        -0.339634       -0.243102  0.241650 -0.470308
# ...

# %% [markdown]
# ## LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
Model = LinearRegression()
Model.fit(x_train_num_rescaled, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = Model.predict(x_test_num_rescaled)

# %%
compare_ = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
compare_.head()
# Out:
#        Actual  Predicted
# 388  0.050569   0.177422
# 588 -0.091186  -0.018790
# 203  0.471014   0.276233
# 546  0.083064   0.175362
# 436  0.142526   0.176197

# %%
sns.histplot(y_test, color='purple', alpha=0.5)
sns.histplot(y_test_pred, color='yellow', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='ASPUS_3A_PCT_CHG', ylabel='Count'>

# %%
from sklearn.metrics import r2_score

y_pred = Model.predict(x_test_num_rescaled)
r_squared = r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-x_test_num_rescaled.shape[1]-1)

# %%
Mean_Absolute_Error = []
Mean_Squared_Error = []
Root_Mean_Squared_Error = []
R_squared = []
Adjusted_r_squared = []

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))
Mean_Absolute_Error.append(metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))
Mean_Squared_Error.append(metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
Root_Mean_Squared_Error.append(np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
                          
print('r_squared: ', r_squared)
R_squared.append(r_squared) 
                          
print('adjusted_r_squared: ', adjusted_r_squared)
Adjusted_r_squared.append(adjusted_r_squared)
# Out:
# Mean Absolute Error:  0.0997040287655581
# Mean Squared Error:  0.01337445436094394
# Root Mean Squared Error:  0.1156479760347925
# r_squared:  0.31697828313234977
# adjusted_r_squared:  0.2568723720479966

# %% [markdown]
# ## RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
Model2 = RandomForestRegressor()
Model2.fit(x_train_num_rescaled, y_train)
# Out:
# RandomForestRegressor()

# %%
y_test_pred = Model2.predict(x_test_num_rescaled)

# %%
compare_ = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
compare_.head()
# Out:
#        Actual  Predicted
# 388  0.050569   0.065233
# 588 -0.091186  -0.077678
# 203  0.471014   0.469963
# 546  0.083064   0.059429
# 436  0.142526   0.147579

# %%
sns.histplot(y_test, color='purple', alpha=0.5)
sns.histplot(y_test_pred, color='yellow', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='ASPUS_3A_PCT_CHG', ylabel='Count'>

# %%
y_pred = Model2.predict(x_test_num_rescaled)
r_squared = r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-x_test_num_rescaled.shape[1]-1)

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))
Mean_Absolute_Error.append(metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))
Mean_Squared_Error.append(metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
Root_Mean_Squared_Error.append(np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
                          
print('r_squared: ', r_squared)
R_squared.append(r_squared) 
                          
print('adjusted_r_squared: ', adjusted_r_squared)
Adjusted_r_squared.append(adjusted_r_squared)
# Out:
# Mean Absolute Error:  0.020474370391021908
# Mean Squared Error:  0.0009933829742992907
# Root Mean Squared Error:  0.03151797858840714
# r_squared:  0.949268798090608
# adjusted_r_squared:  0.9448044523225816

# %% [markdown]
# ## GRADIENT BOOST

# %%
from sklearn.ensemble import GradientBoostingRegressor
Model3=GradientBoostingRegressor()
Model3.fit(x_train_num_rescaled, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_test_pred = Model3.predict(x_test_num_rescaled)

# %%
compare_ = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
compare_.head()
# Out:
#        Actual  Predicted
# 388  0.050569   0.066020
# 588 -0.091186  -0.097313
# 203  0.471014   0.450904
# 546  0.083064   0.093292
# 436  0.142526   0.152562

# %%
sns.histplot(y_test, color='purple', alpha=0.5)
sns.histplot(y_test_pred, color='yellow', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='ASPUS_3A_PCT_CHG', ylabel='Count'>

# %%
y_pred = Model3.predict(x_test_num_rescaled)
r_squared = r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-x_test_num_rescaled.shape[1]-1)

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))
Mean_Absolute_Error.append(metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))
Mean_Squared_Error.append(metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
Root_Mean_Squared_Error.append(np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
                          
print('r_squared: ', r_squared)
R_squared.append(r_squared) 
                          
print('adjusted_r_squared: ', adjusted_r_squared)
Adjusted_r_squared.append(adjusted_r_squared)
# Out:
# Mean Absolute Error:  0.02666420228309635
# Mean Squared Error:  0.0011908069450379721
# Root Mean Squared Error:  0.03450807072320868
# r_squared:  0.9391865281298584
# adjusted_r_squared:  0.9338349426052859

# %% [markdown]
# ## DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor
Model4 = DecisionTreeRegressor()
Model4.fit(x_train_num_rescaled, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_test_pred = Model4.predict(x_test_num_rescaled)

# %%
compare_ = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
compare_.head()
# Out:
#        Actual  Predicted
# 388  0.050569   0.054104
# 588 -0.091186  -0.105696
# 203  0.471014   0.465665
# 546  0.083064   0.072762
# 436  0.142526   0.133831

# %%
sns.histplot(y_test, color='purple', alpha=0.5)
sns.histplot(y_test_pred, color='yellow', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='ASPUS_3A_PCT_CHG', ylabel='Count'>

# %%
y_pred = Model4.predict(x_test_num_rescaled)
r_squared = r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-x_test_num_rescaled.shape[1]-1)

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))
Mean_Absolute_Error.append(metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))
Mean_Squared_Error.append(metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
Root_Mean_Squared_Error.append(np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
                          
print('r_squared: ', r_squared)
R_squared.append(r_squared) 
                          
print('adjusted_r_squared: ', adjusted_r_squared)
Adjusted_r_squared.append(adjusted_r_squared)
# Out:
# Mean Absolute Error:  0.02163566094890511
# Mean Squared Error:  0.001291269473559048
# Root Mean Squared Error:  0.03593423817975063
# r_squared:  0.9340559944378292
# adjusted_r_squared:  0.9282529219483582

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
Model5 = KNeighborsRegressor()
Model5.fit(x_train_num_rescaled, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_test_pred = Model5.predict(x_test_num_rescaled)

# %%
compare_ = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
compare_.head()
# Out:
#        Actual  Predicted
# 388  0.050569   0.074542
# 588 -0.091186  -0.073800
# 203  0.471014   0.147388
# 546  0.083064   0.155964
# 436  0.142526   0.157509

# %%
sns.histplot(y_test, color='purple', alpha=0.5)
sns.histplot(y_test_pred, color='yellow', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='ASPUS_3A_PCT_CHG', ylabel='Count'>

# %%
y_pred = Model5.predict(x_test_num_rescaled)
r_squared = r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-x_test_num_rescaled.shape[1]-1)

# %%
from sklearn import metrics

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_test_pred))
Mean_Absolute_Error.append(metrics.mean_absolute_error(y_test, y_test_pred))

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_test_pred))
Mean_Squared_Error.append(metrics.mean_squared_error(y_test, y_test_pred))

print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
Root_Mean_Squared_Error.append(np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
                          
print('r_squared: ', r_squared)
R_squared.append(r_squared) 
                          
print('adjusted_r_squared: ', adjusted_r_squared)
Adjusted_r_squared.append(adjusted_r_squared)
# Out:
# Mean Absolute Error:  0.05087297043795621
# Mean Squared Error:  0.0055050198808927996
# Root Mean Squared Error:  0.07419582118214475
# r_squared:  0.7188634370447265
# adjusted_r_squared:  0.6941234195046625

# %%
Algorithms = ["Linear_Regression","Random_forest","GBDT","Decision_tree","KNN"]

# %%
data = pd.DataFrame(list(zip(Mean_Absolute_Error,Mean_Squared_Error,Root_Mean_Squared_Error,R_squared,Adjusted_r_squared)),
                   columns = ["Mean_Absolute_Error","Mean_Squared_Error","Root_Mean_Squared_Error","R_squared","Adjusted_r_squared"],
                   index = Algorithms)

# %%
data
# Out:
#                    Mean_Absolute_Error  Mean_Squared_Error  \
# Linear_Regression             0.099704            0.013374
# Random_forest                 0.020474            0.000993
# GBDT                          0.026664            0.001191
# Decision_tree                 0.021636            0.001291
# KNN                           0.050873            0.005505
#
#                    Root_Mean_Squared_Error  R_squared  Adjusted_r_squared
# Linear_Regression                 0.115648   0.316978            0.256872
# Random_forest                     0.031518   0.949269            0.944804
# GBDT                              0.034508   0.939187            0.933835
# Decision_tree                     0.035934   0.934056            0.928253
# KNN                               0.074196   0.718863            0.694123

# %%
data.reset_index(level=0,inplace=True)

# %%
data
# Out:
#                index  Mean_Absolute_Error  Mean_Squared_Error  \
# 0  Linear_Regression             0.099704            0.013374
# 1      Random_forest             0.020474            0.000993
# 2               GBDT             0.026664            0.001191
# 3      Decision_tree             0.021636            0.001291
# 4                KNN             0.050873            0.005505
#
#    Root_Mean_Squared_Error  R_squared  Adjusted_r_squared
# 0                 0.115648   0.316978            0.256872
# 1                 0.031518   0.949269            0.944804
# 2                 0.034508   0.939187            0.933835
# 3                 0.035934   0.934056            0.928253
# 4                 0.074196   0.718863            0.694123

# %%
fig = plt.figure(figsize = (10, 5))
# creating the bar plot
plt.bar(data['index'],data['Mean_Absolute_Error'], color ='yellow',
        width = 0.4)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure().set_figwidth(100)
data.plot(x="index",y=["Mean_Absolute_Error","Mean_Squared_Error","Root_Mean_Squared_Error"],kind="bar")
plt.show()

# %%
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=1,
                    wspace=0.4,
                    hspace=1)

plt.subplot(2,3,1)
plt.bar(data['index'],data['Mean_Absolute_Error'])
plt.title('Mean_Absolute_Error')

plt.subplot(2,3,2)
plt.bar(data['index'],data['Mean_Squared_Error'])
plt.title('Mean_Squared_Error')

plt.subplot(2,3,3)
plt.bar(data['index'],data['Root_Mean_Squared_Error'])
plt.xlabel('Root_Mean_Squared_Error',fontsize=13)

plt.subplot(2,3,4)
plt.bar(data['index'],data['R_squared'])
plt.title('R_squared')


plt.subplot(2,3,5)
plt.bar(data['index'],data['Adjusted_r_squared'])
plt.title('Adjusted_r_squared')

plt.show()

# %%
df
# Out:
#      ASPUS_3A_PCT_CHG  H_RATIO_3A_PCT_CHG  HSN1F_3A_PCT_CHG  \
# 0            0.103627            0.170213         -0.086294
# 1            0.103627            0.170213         -0.086294
# 2            0.103627            0.170213         -0.086294
# 3            0.103627            0.170213         -0.086294
# 4            0.103627            0.170213         -0.086294
# ..                ...                 ...               ...
# 679          0.077628            0.067797          0.317982
# 680          0.045996            0.105263          0.279412
# 681          0.042461            0.309091          0.089286
# 682          0.051818            0.288462          0.121723
# 683          0.061345            0.200000          0.196532
#
#      PERMIT_3A_PCT_CHG  STOCK_MKT_3A_PCT_CHG  BAA_YEILD_10Y_2A_PCT_CHG  \
# 0             0.037433             -3.199388                 -0.420000
# 1             0.037433             -3.199388                 -0.420000
# ...

# %%
from pickle import load,dump

# %%
dump(scaler_,open(r'C:\Users\Jyothi\Desktop\Projects\us_housing\Scalar.pkl','wb'))

# %%
dump(Model2,open(r'C:\Users\Jyothi\Desktop\Projects\us_housing\Random_forest_model.pkl','wb'))

# %%
Random_model=load(open(r'C:\Users\Jyothi\Desktop\Projects\us_housing\Random_forest_model.pkl','rb'))

# %%
print('Enter details:')
Housing_Ratio=float(input('Enter Change in Housing_Ratio: '))
House_sold=float(input('Enter Change in new 1F House sold : '))
onstruction_permit=float(input( 'Enter Change in Current Construction Permits : '))
Stock=float(input('enter Change in Stock Market Movement: '))
Bond=float(input('Enter Change in Bond Market Movement: '))
rate=float(input('enter Change in 10yrs Treasury Rate: '))
Expenditure=float(input('enter Change in Personal Consumer Expenditure: '))
unemployement=float(input('enter Change in Long Term Unemployment Rate: '))
GDP=float(input('enter Change in GDP: '))
Year=float(input('enter Year: '))
Month=float(input('enter Month: '))
# Out:
# Enter details:
# Enter Change in Housing_Ratio: 0.123
# Enter Change in new 1F House sold : 0.987
# Enter Change in Current Construction Permits : 0.008
# enter Change in Stock Market Movement: -0.012
# Enter Change in Bond Market Movement: -0.009
# enter Change in 10yrs Treasury Rate: 0.0008
# enter Change in Personal Consumer Expenditure: 0.666
# enter Change in Long Term Unemployment Rate: 0.0072
# enter Change in GDP: 0.234
# enter Year: 2022
# enter Month: 12

# %%
data_us=pd.DataFrame({'H_RATIO_3A_PCT_CHG':Housing_Ratio,'HSN1F_3A_PCT_CHG':House_sold,"PERMIT_3A_PCT_CHG":
                              onstruction_permit,"STOCK_MKT_3A_PCT_CHG":Stock,"BAA_YEILD_10Y_2A_PCT_CHG":Bond,"US10Y_3A_PCT_CHG":rate,"RPCE_A_PCT_CHG":
                              Expenditure,"UEMP_3A_PCT_CHG":unemployement,"RGDP_M_PCT_CHG":GDP,"YEAR":Year,"MONTH":Month},index=[0])
data_rescaled = pd.DataFrame(scaler_.transform(data_us),
                                     columns = data_us.columns, 
                                    index = data_us.index)

# %%
prediction=Random_model.predict(data_rescaled)

# %%
prediction
# Out:
# array([0.09882714])
